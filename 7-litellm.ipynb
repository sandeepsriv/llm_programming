# %%
from litellm import completion
from IPython.display import Markdown, display

# %%
explain_convexity = [
    {"role": "user", "content": "What is convexity in finance. Explain in simple terms and how does it compare to refrence of convexity made by Nassim Taleb in his books"},
]

# %%
response = completion(model="openai/gpt-4.1", messages=explain_convexity)
reply = response.choices[0].message.content

# %%
display(Markdown(reply))
# Out:
# Certainly! Let’s break down **convexity in finance** and compare it with **Nassim Taleb’s broader concept of convexity**.
#
# ---
#
# ## 1. **Convexity in Finance (Simple Explanation)**
#
# In finance, especially in bond investing, **convexity** measures how the price of a bond changes as interest rates change. Here’s a very simple way to understand it:
#
# - **Duration**: This tells you how much a bond’s price will change when interest rates move a little.
# - **Convexity**: This tells you how much the **duration itself changes** as interest rates move.
#
# **Intuition:**
# - If you graph a bond’s price against interest rates, you get a curved line (not a straight one).
# - **Convexity** describes the **curvature**; higher convexity means the bond price increases more when rates drop, and falls less when rates rise.
#
# **Why do investors like it?**
# - **Higher convexity = less risk**. Bonds with higher convexity gain more when rates go down and lose less when rates go up, compared to bonds with low convexity.
#
# ---
#
# ## 2. **Convexity According to Nassim Taleb**
#
# **Nassim Taleb** popularized a more general and philosophical use of "convexity" in his books (like *Antifragile*). For him, the concept isn’t limited to bonds or finance, but applies to **all systems that interact with randomness and change**.
#
# ### **What does Taleb mean by convexity?**
#
# - **Convexity = Benefiting from volatility or randomness.**
# - If you have a "convex payoff,"** small shocks have a limited downside, but big surprises bring big gains.** (Think lottery tickets: you only lose the price of your ticket, but a win is huge.)
# - **Concavity (= opposite of convexity):** Small gains, but big losses from random events (e.g., selling insurance without reserve).
#
# ### **Everyday Example (not just finance):**
# - If you invest in 10 startups (high failure rate), you lose a little on most, but one could skyrocket (big gain = convex payoff).
# - If you write unhedged insurance contracts, you collect small, regular premiums, but one disaster can ruin you (concave risk).
#
# ---
#
# ## **Summary Table**
#
# |                  | Traditional Finance Convexity         | Taleb's Convexity (General)                  |
# |------------------|--------------------------------------|---------------------------------------------|
# | **Definition**   | Curvature of bond price to interest rate changes | How payoffs (or systems) respond to randomness; gaining more from upside than losing from downside |
# | **Goal**         | Reduce risk & make gains from big interest changes | Benefit from volatility; be "antifragile" (profit from disorder/chaos) |
# | **Result**       | Higher price rise when rates drop, smaller loss when rates rise | Exposure to unlimited upsides, limited downsides |
#
# ---
#
# ## **In Short:**
#
# - **In finance:** Convexity is about how much more a bond’s price moves due to rate changes, giving you protection and extra gain.
# - **In Taleb’s view:** Convexity is any situation where you can lose a little but gain a lot from unexpected events—something to actively seek in life and investing.
#
# **Taleb’s use is broader and focuses on building systems (or personal strategies) that benefit from shocks and randomness, not just changes in interest rates.**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 38
# Output tokens: 727
# Total tokens: 765
# Total cost: 0.5892 cents
